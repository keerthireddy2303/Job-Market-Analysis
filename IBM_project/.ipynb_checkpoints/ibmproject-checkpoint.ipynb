# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 7)
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('ibm.csv')

# %%
data.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4

# %%
data.tail
# Out:
# <bound method NDFrame.tail of                                                 company  \
# 0                                      MM Media Pvt Ltd
# 1                                    find live infotech
# 2                   Softtech Career Infosystem Pvt. Ltd
# 3                                Onboard HRServices LLP
# 4            Spire Technologies and Solutions Pvt. Ltd.
# ...                                                 ...
# 21995       Morgan Stanley Advantage Services Pvt. Ltd.
# 21996  Careernet Technologies Pvt Ltd hiring for Client
# 21997                                    Musk - Startup
# 21998                                      Confidential
# 21999                   Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 0      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1      UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3      UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# ...                                                  ...          ...
# 21995              UG: Any Graduate - Any Specialization   9 - 13 yrs
# 21996  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 5 yrs
# 21997  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    2 - 4 yrs
# 21998  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   7 - 12 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                                        industry  \
# 0              Media / Entertainment / Internet
# 1      Advertising / PR / MR / Event Management
# 2               IT-Software / Software Services
# 3        Banking / Financial Services / Broking
# 4               IT-Software / Software Services
# ...                                         ...
# 21995    Banking / Financial Services / Broking
# 21996           IT-Software / Software Services
# 21997                      Internet / Ecommerce
# 21998           IT-Software / Software Services
# 21999           IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 0      Job Description   Send me Jobs like this Quali...  210516002263
# 1      Job Description   Send me Jobs like this Quali...  210516002391
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 3      Job Description   Send me Jobs like this - Inv...   81016900536
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# ...                                                  ...           ...
# 21995  Job Description   Send me Jobs like this Greet...  241116007152
# 21996  Job Description   Send me Jobs like this Looki...  241116001104
# 21997  Job Description   Send me Jobs like this Work ...  251116900644
# 21998  Job Description   Send me Jobs like this We ar...  231116901329
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#                                      joblocation_address  \
# 0                                                Chennai
# 1                                                Chennai
# 2                                              Bengaluru
# 3      Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                              Bengaluru
# ...                                                  ...
# 21995                                          Bengaluru
# 21996                                 Bengaluru, Gurgaon
# 21997                                          Bengaluru
# 21998                               Delhi NCR, Bengaluru
# 21999                                          Bengaluru
#
#                                                 jobtitle  numberofpositions  \
# 0               Walkin Data Entry Operator (night Shift)                NaN
# 1                     Work Based Onhome Based Part Time.               60.0
# 2                                 Pl/sql Developer - SQL                NaN
# 3                 Manager/ad/partner - Indirect Tax - CA                NaN
# 4                        JAVA Technical Lead (6-8 yrs) -                4.0
# ...                                                  ...                ...
# 21995  Quality Assurance - VP with Morgan Stanley Ban...                2.0
# 21996      Java Backend Developers for a Product Company                NaN
# 21997                    Full Stack Development Engineer                NaN
# 21998  Sr UI Developer/ Technical Lead - Html/ CSS/ J...                NaN
# 21999                              RF Firmware Engineers                NaN
#
#                               payrate                   postdate  \
# 0             1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000
# 1      1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000
# 2          Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 3          Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 4          Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# ...                               ...                        ...
# 21995      Not Disclosed by Recruiter  2016-11-25 22:47:05 +0000
# 21996        8,50,000 - 14,00,000 P.A  2016-11-24 22:47:05 +0000
# 21997      Not Disclosed by Recruiter  2016-11-25 22:47:05 +0000
# 21998      Not Disclosed by Recruiter  2016-11-27 22:47:05 +0000
# 21999       12,00,000 - 22,00,000 P.A  2016-11-25 22:47:05 +0000
#
#             site_name                                 skills  \
# 0                 NaN                                   ITES
# 1                 NaN                              Marketing
# 2                 NaN  IT Software - Application Programming
# 3                 NaN                               Accounts
# 4                 NaN  IT Software - Application Programming
# ...               ...                                    ...
# 21995  www.naukri.com             IT Software - QA & Testing
# 21996  www.naukri.com  IT Software - Application Programming
# 21997  www.naukri.com  IT Software - Application Programming
# 21998  www.naukri.com  IT Software - Application Programming
# 21999  www.naukri.com       IT Software - System Programming
#
#                                 uniq_id
# 0      43b19632647068535437c774b6ca6cf8
# 1      d4c72325e57f89f364812b5ed5a795f0
# 2      c47df6f4cfdf5b46f1fd713ba61b9eba
# 3      115d28f140f694dd1cc61c53d03c66ae
# 4      a12553fc03bc7bcced8b1bb8963f97b4
# ...                                 ...
# 21995  ef40136e3b0c0abdab695d979a4b7153
# 21996  acb80b7bb109fa76d22d1f11c6e16c6a
# 21997  f6f2885a6c87572616fb766029a0d284
# 21998  c6f6538cb1007dd02c1b4b77909b3d38
# 21999  74fec26df6e1c0be0171311a2f03f180
#
# [22000 rows x 14 columns]>

# %%
print(data.isnull().sum())
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
data.dropna()
# Out:
#                                                  company  \
# 12171                        Waytogo Consultants Pvt Ltd
# 12176  QUANTUM ASSET MANAGEMENT COMPANY PRIVATE LIMITED.
# 12181    BIO JOBZ( Medulla Recruitment Services Pvt Ltd)
# 12210                AERONUBE TECHNOLOGY PRIVATE LIMITED
# 12221                  Zirca Digital Solutions Pvt. Ltd.
# ...                                                  ...
# 21945  Career Trackers and Consulting hiring for A ve...
# 21948                AERONUBE TECHNOLOGY PRIVATE LIMITED
# 21961  The Catalyst hiring for Multinational Manufact...
# 21976         Connectpro Management Consultants Pvt Ltd.
# 21995        Morgan Stanley Advantage Services Pvt. Ltd.
#
#                                                education   experience  \
# 12171              UG: Any Graduate - Any Specialization    2 - 5 yrs
# 12176  UG: Any Graduate - Any Specialization PG:Any P...    3 - 6 yrs
# 12181   UG: B.Tech/B.E. - Any Specialization, Mechanical  10 - 15 yrs
# 12210  UG: Any Graduate - Any Specialization PG:Any P...   8 - 10 yrs
# 12221  UG: Any Graduate - Any Specialization PG:Any P...    2 - 5 yrs
# ...                                                  ...          ...
# 21945  UG: Any Graduate, Graduation Not Required PG:A...   5 - 10 yrs
# 21948  UG: Any Graduate - Any Specialization PG:MBA/P...  12 - 16 yrs
# 21961  UG: Any Graduate - Any Specialization PG:CA Do...   7 - 10 yrs
# 21976  UG: B.Tech/B.E. - Any Specialization, Computer...  15 - 19 yrs
# 21995              UG: Any Graduate - Any Specialization   9 - 13 yrs
#
#                                      industry  \
# 12171  Banking / Financial Services / Broking
# 12176         IT-Software / Software Services
# 12181    Pharma / Biotech / Clinical Research
# 12210  Banking / Financial Services / Broking
# 12221        Media / Entertainment / Internet
# ...                                       ...
# 21945         IT-Software / Software Services
# 21948                             Telecom/ISP
# 21961                 FMCG / Foods / Beverage
# 21976            Semiconductors / Electronics
# 21995  Banking / Financial Services / Broking
#
#                                           jobdescription         jobid  \
# 12171  Job Description   Send me Jobs like this Handl...   91116600303
# 12176  Job Description   Send me Jobs like this The c...  230916600730
# 12181  Job Description   Send me Jobs like this 1.PR ...   51116600126
# 12210  Job Description   Send me Jobs like this Greet...  101116600372
# 12221  Job Description   Send me Jobs like this - Dev...  181016600001
# ...                                                  ...           ...
# 21945  Job Description   Send me Jobs like this We ha...   70916000307
# 21948  Job Description   Send me Jobs like this Greet...  241116003093
# 21961  Job Description   Send me Jobs like this To co...  120316002509
# 21976  Job Description   Send me Jobs like this The c...  270916002004
# 21995  Job Description   Send me Jobs like this Greet...  241116007152
#
#                                      joblocation_address  \
# 12171        Mumbai, Navi Mumbai, Mumbai Suburbs, Mumbai
# 12176                                             Mumbai
# 12181                                             Mumbai
# 12210                                             Mumbai
# 12221                                  Bengaluru, Mumbai
# ...                                                  ...
# 21945                            Bengaluru, Pune, Mumbai
# 21948  Hyderabad, Ahmedabad, Bengaluru Bangalore, Che...
# 21961                                          Bengaluru
# 21976                                          Bengaluru
# 21995                                          Bengaluru
#
#                                                 jobtitle  numberofpositions  \
# 12171                            Sales Support Executive                2.0
# 12176                     Software Developer - Asp . Net                6.0
# 12181                                Capital Procurement                1.0
# 12210  Risk & Compliance â?? Financial Services / Mum...                2.0
# 12221                Sales Executive / Assistant Manager                2.0
# ...                                                  ...                ...
# 21945  Network Security Specialist for Pune, Mumbai &...               10.0
# 21948  City Lead - Relationship Management / Pan Indi...               10.0
# 21961  Internal Audit Manager - Global Audit- MNC- Ba...                1.0
# 21976                           SW Architecture Engineer                1.0
# 21995  Quality Assurance - VP with Morgan Stanley Ban...                2.0
#
#                                                  payrate  \
# 12171                            2,50,000 - 6,00,000 P.A
# 12176                         Not Disclosed by Recruiter
# 12181                         Not Disclosed by Recruiter
# 12210                         Not Disclosed by Recruiter
# 12221  5,00,000 - 9,00,000 P.A. Reimbursement & Medic...
# ...                                                  ...
# 21945                               Best In The Industry
# 21948                         Not Disclosed by Recruiter
# 21961                          22,50,000 - 30,00,000 P.A
# 21976                         Not Disclosed by Recruiter
# 21995                         Not Disclosed by Recruiter
#
#                         postdate       site_name  \
# 12171  2016-11-08 19:48:31 +0000  www.naukri.com
# 12176  2016-12-02 19:48:31 +0000  www.naukri.com
# 12181  2016-11-04 19:48:31 +0000  www.naukri.com
# 12210  2016-11-09 19:48:32 +0000  www.naukri.com
# 12221  2016-11-09 19:48:32 +0000  www.naukri.com
# ...                          ...             ...
# 21945  2016-11-25 22:47:03 +0000  www.naukri.com
# 21948  2016-11-24 22:47:03 +0000  www.naukri.com
# 21961  2017-01-08 22:47:04 +0000  www.naukri.com
# 21976  2016-11-24 22:47:04 +0000  www.naukri.com
# 21995  2016-11-25 22:47:05 +0000  www.naukri.com
#
#                                       skills                           uniq_id
# 12171                     Financial Services  18ba67833dff4e7962ade4b615bb4cf2
# 12176  IT Software - Application Programming  d0f22f82c236f2291123505335c9b10a
# 12181                           Supply Chain  284a5c4f3287982760eabe250e6ba0c1
# 12210                               Accounts  71183fc0a19e2c5cf47b76d787a649a2
# 12221                                  Sales  bb4231c5bcd75a47b8ca0673241db645
# ...                                      ...                               ...
# 21945   IT Software - Network Administration  c5a9b84defcce6ec9702743b348fba7b
# 21948                                  Sales  6e8e83a8c54e0897319f693edce19ed8
# 21961                               Accounts  6768d37da11cb830090ee46c75e20cfb
# 21976                 IT Software - Embedded  11287c3d58b5193e90b01cfdc260db33
# 21995             IT Software - QA & Testing  ef40136e3b0c0abdab695d979a4b7153
#
# [485 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
data.describe()
# Out:
#               jobid  numberofpositions
# count  2.200000e+04        4464.000000
# mean   1.561171e+11          45.116935
# std    9.423956e+10         186.197193
# min    1.011600e+10           1.000000
# 25%    6.121650e+10           2.000000
# 50%    1.602169e+11           4.000000
# 75%    2.502166e+11          10.000000
# max    3.112155e+11        2000.000000

# %%
data.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
data.shape
# Out:
# (22000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              21996 non-null  object
#  1   education            20004 non-null  object
#  2   experience           21996 non-null  object
#  3   industry             21995 non-null  object
#  4   jobdescription       21996 non-null  object
#  5   jobid                22000 non-null  int64
#  6   joblocation_address  21499 non-null  object
#  7   jobtitle             22000 non-null  object
#  8   numberofpositions    4464 non-null   float64
#  9   payrate              21903 non-null  object
#  10  postdate             21977 non-null  object
#  11  site_name            3987 non-null   object
#  12  skills               21472 non-null  object
#  13  uniq_id              22000 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.3+ MB

# %%
data.isnull()
# Out:
#        company  education  experience  industry  jobdescription  jobid  \
# 0        False      False       False     False           False  False
# 1        False      False       False     False           False  False
# 2        False      False       False     False           False  False
# 3        False      False       False     False           False  False
# 4        False      False       False     False           False  False
# ...        ...        ...         ...       ...             ...    ...
# 21995    False      False       False     False           False  False
# 21996    False      False       False     False           False  False
# 21997    False      False       False     False           False  False
# 21998    False      False       False     False           False  False
# 21999    False      False       False     False           False  False
#
#        joblocation_address  jobtitle  numberofpositions  payrate  postdate  \
# 0                    False     False               True    False     False
# 1                    False     False              False    False     False
# 2                    False     False               True    False     False
# 3                    False     False               True    False     False
# 4                    False     False              False    False     False
# ...                    ...       ...                ...      ...       ...
# 21995                False     False              False    False     False
# 21996                False     False               True    False     False
# 21997                False     False               True    False     False
# 21998                False     False               True    False     False
# 21999                False     False               True    False     False
#
#        site_name  skills  uniq_id
# 0           True   False    False
# 1           True   False    False
# 2           True   False    False
# 3           True   False    False
# 4           True   False    False
# ...          ...     ...      ...
# 21995      False   False    False
# 21996      False   False    False
# 21997      False   False    False
# 21998      False   False    False
# 21999      False   False    False
#
# [22000 rows x 14 columns]

# %%
data['company'].value_counts().head(10)
# Out:
# company
# Indian Institute of Technology Bombay           403
# Confidential                                    393
# National Institute of Industrial Engineering    185
# Oracle India Pvt. Ltd.                          151
# JPMorgan Chase                                  135
# Godrej Industries Ltd                           125
# Unitforce technologies Pvt. Ltd.                100
# Capgemini                                        98
# HCL Technologies                                 95
# Axis Jobs                                        92
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(15,5))
data['company'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='company'>

# %%
data['industry'].value_counts().head(10)
# Out:
# industry
# IT-Software / Software Services                  9216
# Education / Teaching / Training                  1322
# BPO / Call Centre / ITES                         1254
# Banking / Financial Services / Broking           1238
# Recruitment / Staffing                           1129
# Internet / Ecommerce                              738
# Pharma / Biotech / Clinical Research              525
# Medical / Healthcare / Hospitals                  495
# Automobile / Auto Anciliary / Auto Components     478
# Construction / Engineering / Cement / Metals      449
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(15,5))
data['industry'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='industry'>

# %%
data['jobtitle'].value_counts().head(10)
# Out:
# jobtitle
# Business Development Executive    93
# Business Development Manager      92
# Software Engineer                 81
# Project Manager                   67
# Android Developer                 65
# Web Designer                      61
# Content Writer                    59
# Senior Software Engineer          58
# Sales Executive                   56
# PHP Developer                     54
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(15,5))
data['jobtitle'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='jobtitle'>

# %%
data['skills'].value_counts().head(10)
# Out:
# skills
# IT Software - Application Programming    5989
# Sales                                    2893
# ITES                                     1640
# Teaching                                 1091
# HR                                        928
# Marketing                                 868
# Accounts                                  860
# Production                                667
# Medical                                   418
# Financial Services                        413
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(15,5))
data['skills'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='skills'>

# %%
replacements = {
   'joblocation_address': {
      r'(Bengaluru/Bangalore)': 'Bangalore',
      r'Bengaluru': 'Bangalore',
      r'Hyderabad / Secunderabad': 'Hyderabad',
      r'Mumbai , Mumbai': 'Mumbai',
      r'Noida': 'NCR',
      r'Delhi': 'NCR',
      r'Gurgaon': 'NCR', 
      r'Delhi/NCR(National Capital Region)': 'NCR',
      r'Delhi , Delhi': 'NCR',
      r'Noida , Noida/Greater Noida': 'NCR',
      r'Ghaziabad': 'NCR',
      r'Delhi/NCR(National Capital Region) , Gurgaon': 'NCR',
      r'NCR , NCR': 'NCR',
      r'NCR/NCR(National Capital Region)': 'NCR',
      r'NCR , NCR/Greater NCR': 'NCR',
      r'NCR/NCR(National Capital Region) , NCR': 'NCR', 
      r'NCR , NCR/NCR(National Capital Region)': 'NCR', 
      r'Bangalore , Bangalore / Bangalore': 'Bangalore',
      r'Bangalore , karnataka': 'Bangalore',
      r'NCR/NCR(National Capital Region)': 'NCR',
      r'NCR/Greater NCR': 'NCR',
      r'NCR/NCR(National Capital Region) , NCR': 'NCR'
       
   }
}

data.replace(replacements, regex=True, inplace=True)
y = data['joblocation_address'].value_counts()

# %%
most_job_posting_city=data['joblocation_address'].value_counts().head()
f ,ax=plt.subplots(figsize=(15,5))
most_job_posting_city.plot(kind = 'bar')
# Out:
# <Axes: xlabel='joblocation_address'>

# %%
pay_split = data['payrate'].str[1:-1].str.split('-', expand=True)
pay_split.head()
# Out:
#                           0                    1     2     3     4     5     6
# 0                  ,50,000           2,25,000 P.  None  None  None  None  None
# 1                  ,50,000    2,50,000 P.A. 2000  None  None  None  None  None
# 2  ot Disclosed by Recruite                 None  None  None  None  None  None
# 3  ot Disclosed by Recruite                 None  None  None  None  None  None
# 4  ot Disclosed by Recruite                 None  None  None  None  None  None

# %%
#remove space in left and right 
pay_split[0] =  pay_split[0].str.strip()
#remove comma 
pay_split[0] = pay_split[0].str.replace(',', '')
#remove all character in two condition
# 1 remove if only character
# 2 if start in number remove after all character
pay_split[0] = pay_split[0].str.replace(r'\D.*', '')
#display 
pay_split[0].head()
# Out:
# 0                       50000
# 1                       50000
# 2    ot Disclosed by Recruite
# 3    ot Disclosed by Recruite
# 4    ot Disclosed by Recruite
# Name: 0, dtype: object

# %%
#remove space in left and right 
pay_split[1] =  pay_split[1].str.strip()
#remove comma 
pay_split[1] = pay_split[1].str.replace(',', '')
#remove all character in two condition
# 1 remove if only character
# 2 if start in number remove after all character
pay_split[1] = pay_split[1].str.replace(r'\D.*', '')
#display 
pay_split[1].head()
# Out:
# 0           225000 P.
# 1    250000 P.A. 2000
# 2                None
# 3                None
# 4                None
# Name: 1, dtype: object

# %%
pay_split[0] = pd.to_numeric(pay_split[0], errors='coerce')
pay_split[1] = pd.to_numeric(pay_split[1], errors='coerce')

# %%
pay=pd.concat([pay_split[0], pay_split[1]], axis=1, sort=False)

# %%
pay.rename(columns={0:'min_pay', 1:'max_pay'}, inplace=True)
pay.head()
# Out:
#    min_pay  max_pay
# 0  50000.0      NaN
# 1  50000.0      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
data=pd.concat([data, pay], axis=1, sort=False)

# %%
data.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bangalore
# 3  Mumbai, Bangalore, Kolkata, Chennai, Coimbator...
# 4                                          Bangalore
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
#
#    min_pay  max_pay
# 0  50000.0      NaN
# 1  50000.0      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
experience_split = data['experience'].str[0:-1].str.split('-', expand=True)
experience_split.head()
# Out:
#      0       1     2
# 0   0     1 yr  None
# 1   0     0 yr  None
# 2   4     8 yr  None
# 3  11    15 yr  None
# 4   6     8 yr  None

# %%
#remove space in left and right 
experience_split[1] =  experience_split[1].str.strip()
#remove comma 
experience_split[1] = experience_split[1].str.replace('yr', '')
#remove all character in two condition
# 1 remove if only character
# 2 if start in number remove after all character
experience_split[1] = experience_split[1].str.replace(r'yr', '')
#display 
experience_split[1].head()
# Out:
# 0     1
# 1     0
# 2     8
# 3    15
# 4     8
# Name: 1, dtype: object

# %%
experience_split[0] = pd.to_numeric(experience_split[0], errors='coerce')
experience_split[1] = pd.to_numeric(experience_split[1], errors='coerce')

# %%
experience=pd.concat([experience_split[0], experience_split[1]], axis=1, sort=False)

# %%
experience.rename(columns={0:'min_experience', 1:'max_experience'}, inplace=True)
experience.head()
# Out:
#    min_experience  max_experience
# 0             0.0             1.0
# 1             0.0             0.0
# 2             4.0             8.0
# 3            11.0            15.0
# 4             6.0             8.0

# %%
data=pd.concat([data, experience], axis=1, sort=False)
data.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bangalore
# 3  Mumbai, Bangalore, Kolkata, Chennai, Coimbator...
# 4                                          Bangalore
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
#
#    min_pay  max_pay  min_experience  max_experience
# 0  50000.0      NaN             0.0             1.0
# 1  50000.0      NaN             0.0             0.0
# 2      NaN      NaN             4.0             8.0
# 3      NaN      NaN            11.0            15.0
# 4      NaN      NaN             6.0             8.0

# %%
data['avg_pay']=(data['min_pay'].values + data['max_pay'].values)/2
data['avg_experience']=(data['min_experience'].values + data['max_experience'].values)/2

# %%
f,ax=plt.subplots(figsize=(15,5))

sns.stripplot(x='min_experience', y='min_pay', data=data, jitter=True)
# Out:
# <Axes: xlabel='min_experience', ylabel='min_pay'>

# %%
f,ax=plt.subplots(figsize=(15,5))
sns.pointplot(x='min_experience', y='min_pay', data=data)
# Out:
# <Axes: xlabel='min_experience', ylabel='min_pay'>

# %%
f,ax=plt.subplots(figsize=(15,5))
sns.stripplot(x='max_experience', y='max_pay', data=data, jitter=True)
# Out:
# <Axes: xlabel='max_experience', ylabel='max_pay'>

# %%
f,ax=plt.subplots(figsize=(15,5))
sns.pointplot(x='max_experience', y='max_pay', data=data)
# Out:
# <Axes: xlabel='max_experience', ylabel='max_pay'>

# %%
sns.pairplot(data, 
             size=5, aspect=0.9, 
             x_vars=["min_experience","max_experience"],
             y_vars=["min_pay"],
             kind="reg")

# %%
sns.pairplot(data, 
             size=5, aspect=0.9, 
             x_vars=["min_experience","max_experience"],
             y_vars=["max_pay"],
             kind="reg")

# %%
sns.jointplot(x='avg_experience', y='avg_pay', data=data, 
              kind="kde",xlim={0,15}, ylim={0,1000000})

# %%
data[['min_pay','industry']].groupby(["industry"]).median().sort_values(by='min_pay',ascending=False).head(10).plot.bar(color='lightgreen')
# Out:
# <Axes: xlabel='industry'>

# %%
data[['max_pay','industry']].groupby(["industry"]).median().sort_values(by='max_pay',ascending=False).head(10).plot.bar(color='lightblue')
# Out:
# <Axes: xlabel='industry'>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
def convert_salary(salary):
    try:
        salary = salary.replace('P.A', '').replace(' ', '').replace(',', '')
        low, high = map(int, salary.split('-'))
        return (low + high) / 2
    except:
        return np.nan

# Apply the function to the payrate column
data['payrate'] = data['payrate'].apply(convert_salary)

# Drop rows with NaN values in the target variable
data = data.dropna(subset=['payrate'])

# Convert the target variable to numeric
data['payrate'] = pd.to_numeric(data['payrate'])

# %%
X = data.drop(columns=['payrate'])
y = data['payrate']

# %%
categorical_features = ['company', 'education', 'experience', 'industry', 'jobdescription', 'joblocation_address', 'site_name', 'skills']
numerical_features = ['numberofpositions']

# Create preprocessing pipelines for both categorical and numerical features
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine transformers into a preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

    # Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Train the model
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['numberofpositions']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['company', 'education',
#                                                    'experience', 'industry',
#                                                    'jobdescription',
#                                                    'joblocation_address',
#                                                    'site_name', 'skills'])])),
#                 ('regressor', LinearRegression())])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Make predictions
y_pred = model.predict(X_test)

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 233828.46428477776
# Mean Squared Error (MSE): 123689609328.74023
# Root Mean Squared Error (RMSE): 351695.33594965434
# R-squared (R²): 0.646180559476287

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=45)
plt.title("Confusion Matrix")
plt.show()

# %%
import pickle
from sklearn.linear_model import LinearRegression

# Example: Save the trained model
model = LinearRegression()  # Replace with your trained model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
print(type(model))
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>
